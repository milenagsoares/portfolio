# %% [markdown]
# #SALES DEPARTAMENT SOLUTION
# #UNDERSTAND THE PROBLEM STATEMENT AND BUSINESS CASE
#
# - For companies to become competitive and skyrocket their growth, they need to leverage AI/ML to develop predictive models to forecast sales in the future.
#
# - Predictive models attempt at forecasting future sales based on historical data while taking into account seasonaly effects, demand, holidays, promotions and competition
#
# - In this project, you work as a data scientist in the sales department and the sales team provided you with data from 1115 stores
#
# - The objective is to predict future daily sales based on the features
#
# O objetivo do modelo é prever o volume de vendas diárias com base nas variáveis explicativas (ex.: promoções, feriados, número de clientes, etc.).

# %%
#import libraries and dataset
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
sales_train_df = pd.read_csv('/content/drive/My Drive/datascience/train.csv')
# Out:
# <ipython-input-3-2c2281822f33>:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   sales_train_df = pd.read_csv('/content/drive/My Drive/datascience/train.csv')

# %%
sales_train_df.head(5)
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %% [markdown]
# - almost a million observation
# - 1115 unique stores
# - Note that sales is the target variable(that's what we are trying to predict)
# - ID: transaction id (combination of store and date)
# - Store: unique store ID
# - Sales: sales/day, this is the target variable
# - Customers: number of customers on a given day
# - Open: Boolean to say whether a store is open or closed (0 = closed, 1 = open)
# - Promo: describes if store is running a promo on that day or not
# - SatateHoliday: Indicate which state holiday (a= public holiday, b = Easter holiday, c = Christmas, 0 = None)
# - SchoolHoliday: Indicates if the (store, date) was affected by the closure of public schools

# %%
sales_train_df.tail(10)
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 1017199   1106          2  2013-01-01      0          0     0      0
# 1017200   1107          2  2013-01-01      0          0     0      0
# 1017201   1108          2  2013-01-01      0          0     0      0
# 1017202   1109          2  2013-01-01      0          0     0      0
# 1017203   1110          2  2013-01-01      0          0     0      0
# 1017204   1111          2  2013-01-01      0          0     0      0
# 1017205   1112          2  2013-01-01      0          0     0      0
# 1017206   1113          2  2013-01-01      0          0     0      0
# 1017207   1114          2  2013-01-01      0          0     0      0
# 1017208   1115          2  2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday
# 1017199            a              1
# 1017200            a              1
# 1017201            a              1
# 1017202            a              1
# 1017203            a              1
# 1017204            a              1
# 1017205            a              1
# 1017206            a              1
# 1017207            a              1
# 1017208            a              1

# %%
sales_train_df.info()
#9 columns in total
#8 features, each contains 1017209 data points
#1 target variable (sales)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017209 entries, 0 to 1017208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   Store          1017209 non-null  int64
#  1   DayOfWeek      1017209 non-null  int64
#  2   Date           1017209 non-null  object
#  3   Sales          1017209 non-null  int64
#  4   Customers      1017209 non-null  int64
#  5   Open           1017209 non-null  int64
#  6   Promo          1017209 non-null  int64
#  7   StateHoliday   1017209 non-null  object
#  8   SchoolHoliday  1017209 non-null  int64
# dtypes: int64(7), object(2)
# memory usage: 69.8+ MB

# %%
sales_train_df.describe()
#Average sales amount per day = 5773 euros, minimum sales per day = 0, maximum sales per day = 41551
#Average number of customers = 633, minimum number of customers = 0, maximum number of customers = 7388
# Out:
#               Store     DayOfWeek         Sales     Customers          Open  \
# count  1.017209e+06  1.017209e+06  1.017209e+06  1.017209e+06  1.017209e+06
# mean   5.584297e+02  3.998341e+00  5.773819e+03  6.331459e+02  8.301067e-01
# std    3.219087e+02  1.997391e+00  3.849926e+03  4.644117e+02  3.755392e-01
# min    1.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.800000e+02  2.000000e+00  3.727000e+03  4.050000e+02  1.000000e+00
# 50%    5.580000e+02  4.000000e+00  5.744000e+03  6.090000e+02  1.000000e+00
# 75%    8.380000e+02  6.000000e+00  7.856000e+03  8.370000e+02  1.000000e+00
# max    1.115000e+03  7.000000e+00  4.155100e+04  7.388000e+03  1.000000e+00
#
#               Promo  SchoolHoliday
# count  1.017209e+06   1.017209e+06
# mean   3.815145e-01   1.786467e-01
# std    4.857586e-01   3.830564e-01
# min    0.000000e+00   0.000000e+00
# 25%    0.000000e+00   0.000000e+00
# 50%    0.000000e+00   0.000000e+00
# 75%    1.000000e+00   0.000000e+00
# max    1.000000e+00   1.000000e+00

# %%
#import store information data
store_info_df = pd.read_csv('/content/drive/My Drive/datascience/store.csv')

# %% [markdown]
# - StoreType: categorical variable to indicate type of store (a, b, c, d)
# - Assortment: describes an assortment level: a = basic, b = extra, c = extended
# - CompetitionDistance(meters): distance to closest competitor store
# - CompetitionOpenSince [Month/Year]: provides an estimate of the date when competition was open
# - Promo2: Promo2 is a continuing consecutive promotion for some stores (0 -  store is not participating, 1 = store is participating)
# - Promo2Since year/week: date when the store started participating in promo2
# - PromoInterval: describes the consecutive intervals Promo2 is started, naming the months the promotion is started anew. E.g. "Feb,May,Aug,Nov" means each round starts in February, May, August, November of any given year for that store

# %%
store_info_df.head(5)
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# 2  Jan,Apr,Jul,Oct
# 3              NaN
# 4              NaN

# %%
#let's do the same for the store_info_df data
#Note that the previous dataframe includes the transactions recorded per day (in millions)
#this dataframe only includes information about the unique 1115 stores that are part of this study
store_info_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1115 entries, 0 to 1114
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Store                      1115 non-null   int64
#  1   StoreType                  1115 non-null   object
#  2   Assortment                 1115 non-null   object
#  3   CompetitionDistance        1112 non-null   float64
#  4   CompetitionOpenSinceMonth  761 non-null    float64
#  5   CompetitionOpenSinceYear   761 non-null    float64
#  6   Promo2                     1115 non-null   int64
#  7   Promo2SinceWeek            571 non-null    float64
#  8   Promo2SinceYear            571 non-null    float64
#  9   PromoInterval              571 non-null    object
# dtypes: float64(5), int64(2), object(3)
# memory usage: 87.2+ KB

# %%
store_info_df.describe()
#on average, the competition distance is 5404 meters away (5.4 kms)
# Out:
#             Store  CompetitionDistance  CompetitionOpenSinceMonth  \
# count  1115.00000          1112.000000                 761.000000
# mean    558.00000          5404.901079                   7.224704
# std     322.01708          7663.174720                   3.212348
# min       1.00000            20.000000                   1.000000
# 25%     279.50000           717.500000                   4.000000
# 50%     558.00000          2325.000000                   8.000000
# 75%     836.50000          6882.500000                  10.000000
# max    1115.00000         75860.000000                  12.000000
#
#        CompetitionOpenSinceYear       Promo2  Promo2SinceWeek  Promo2SinceYear
# count                761.000000  1115.000000       571.000000       571.000000
# mean                2008.668857     0.512108        23.595447      2011.763573
# std                    6.195983     0.500078        14.141984         1.674935
# min                 1900.000000     0.000000         1.000000      2009.000000
# 25%                 2006.000000     0.000000        13.000000      2011.000000
# 50%                 2010.000000     1.000000        22.000000      2012.000000
# 75%                 2013.000000     1.000000        37.000000      2013.000000
# max                 2015.000000     1.000000        50.000000      2015.000000

# %% [markdown]
# #Explore dataset

# %%
#explore sales training data
#let's see if we have any missing data, (We dont)
sns.heatmap(sales_train_df.isnull(), yticklabels = False, cbar = False, cmap = "Blues")
# Out:
# <Axes: >

# %%
sales_train_df.hist(bins = 30, figsize = (20, 20), color = 'r')
#Average 600 customers per day, maximum is 4500 (note that we can't see the outlier at 7388)
#Data is equally distributed across various days of the week
#stores are open ~80% of the time
#data is equally distributed among all stores(no bias)
#promo #1 was running ~40% of the time
#Average sales around 5000-6000 euros
#school holidays are around ~18% of the time
# Out:
# array([[<Axes: title={'center': 'Store'}>,
#         <Axes: title={'center': 'DayOfWeek'}>,
#         <Axes: title={'center': 'Sales'}>],
#        [<Axes: title={'center': 'Customers'}>,
#         <Axes: title={'center': 'Open'}>,
#         <Axes: title={'center': 'Promo'}>],
#        [<Axes: title={'center': 'SchoolHoliday'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %% [markdown]
# - DayOfWeek (Day of the Week):
#
#   - This chart shows the distribution of days of the week (1 to 7). It is uniform, indicating that observations are evenly distributed across all days, with no particular day being under- or overrepresented.
#
# - Sales:
#   - This chart displays the distribution of daily sales. It is skewed (non-uniform), with most sales concentrated at lower values (less than 10,000) and few occurrences of very high sales
#   - This is important because sales are the target variable to predict
#
# - Customers:
#   - This chart is also skewed, showing that most stores serve a small number of customers on a given day, while only a few stores serve significantly more customers
#
# - Promo: This chart shows whether stores were running promotions on a given day. There are more dats without promotions (0) than with promotions (1), indicating that promotions are not a daily occurrence
#
# SchoolHoliday (School Holidays):
#
# This chart shows whether a store's operations were affected by school holidays. Most observations correspond to days without any school holiday impact (0).

# %%
sales_train_df['Customers'].max()
# Out:
# 7388

# %%
#let's see how many stores are open and closed
closed_train_df = sales_train_df[sales_train_df['Open'] == 0]
open_train_df = sales_train_df[sales_train_df['Open'] == 1]

# %%
#Count the number of stores that are open and closed
print("Total =", len(sales_train_df))
print("Number of closed stores =", len(closed_train_df))
print("Number of open stores  =", len(open_train_df))
# Out:
# Total = 1017209
# Number of closed stores = 172817
# Number of open stores  = 844392

# %%
#only keep open stores and remove closed stores
sales_train_df = sales_train_df[sales_train_df['Open'] == 1]

# %%
sales_train_df
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 0            1          5  2015-07-31   5263        555     1      1
# 1            2          5  2015-07-31   6064        625     1      1
# 2            3          5  2015-07-31   8314        821     1      1
# 3            4          5  2015-07-31  13995       1498     1      1
# 4            5          5  2015-07-31   4822        559     1      1
# ...        ...        ...         ...    ...        ...   ...    ...
# 1016776    682          2  2013-01-01   3375        566     1      0
# 1016827    733          2  2013-01-01  10765       2377     1      0
# 1016863    769          2  2013-01-01   5035       1248     1      0
# 1017042    948          2  2013-01-01   4491       1039     1      0
# 1017190   1097          2  2013-01-01   5961       1405     1      0
#
#         StateHoliday  SchoolHoliday
# 0                  0              1
# 1                  0              1
# 2                  0              1
# 3                  0              1
# 4                  0              1
# ...              ...            ...
# 1016776            a              1
# 1016827            a              1
# 1016863            a              1
# 1017042            a              1
# 1017190            a              1
#
# [844392 rows x 9 columns]

# %%
#Let's drop the open column since it has no meaning now
sales_train_df.drop(['Open'], axis = 1, inplace = True)
# Out:
# <ipython-input-19-0333a65e0391>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales_train_df.drop(['Open'], axis = 1, inplace = True)

# %%
sales_train_df
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Promo StateHoliday  \
# 0            1          5  2015-07-31   5263        555      1            0
# 1            2          5  2015-07-31   6064        625      1            0
# 2            3          5  2015-07-31   8314        821      1            0
# 3            4          5  2015-07-31  13995       1498      1            0
# 4            5          5  2015-07-31   4822        559      1            0
# ...        ...        ...         ...    ...        ...    ...          ...
# 1016776    682          2  2013-01-01   3375        566      0            a
# 1016827    733          2  2013-01-01  10765       2377      0            a
# 1016863    769          2  2013-01-01   5035       1248      0            a
# 1017042    948          2  2013-01-01   4491       1039      0            a
# 1017190   1097          2  2013-01-01   5961       1405      0            a
#
#          SchoolHoliday
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1
# ...                ...
# 1016776              1
# 1016827              1
# 1016863              1
# 1017042              1
# 1017190              1
#
# [844392 rows x 8 columns]

# %%
sales_train_df.describe()
# Out:
#                Store      DayOfWeek          Sales      Customers  \
# count  844392.000000  844392.000000  844392.000000  844392.000000
# mean      558.422920       3.520361    6955.514291     762.728395
# std       321.731914       1.723689    3104.214680     401.227674
# min         1.000000       1.000000       0.000000       0.000000
# 25%       280.000000       2.000000    4859.000000     519.000000
# 50%       558.000000       3.000000    6369.000000     676.000000
# 75%       837.000000       5.000000    8360.000000     893.000000
# max      1115.000000       7.000000   41551.000000    7388.000000
#
#                Promo  SchoolHoliday
# count  844392.000000  844392.000000
# mean        0.446352       0.193580
# std         0.497114       0.395103
# min         0.000000       0.000000
# 25%         0.000000       0.000000
# 50%         0.000000       0.000000
# 75%         1.000000       0.000000
# max         1.000000       1.000000

# %%
#let's see if we have any missing data in the store information dataframe
sns.heatmap(store_info_df.isnull(), yticklabels = False, cbar = False, cmap = "Blues")
# Out:
# <Axes: >

# %%
#let's take a look at the missing values in the 'competitionDistance'
#only 3 rows are missing
store_info_df[store_info_df['CompetitionDistance'].isnull()]
# Out:
#      Store StoreType Assortment  CompetitionDistance  \
# 290    291         d          a                  NaN
# 621    622         a          c                  NaN
# 878    879         d          a                  NaN
#
#      CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 290                        NaN                       NaN       0
# 621                        NaN                       NaN       0
# 878                        NaN                       NaN       1
#
#      Promo2SinceWeek  Promo2SinceYear    PromoInterval
# 290              NaN              NaN              NaN
# 621              NaN              NaN              NaN
# 878              5.0           2013.0  Feb,May,Aug,Nov

# %%
#let's take a look at the missing values in the 'competitionOpenSinceMonth'
#Many rows are missing = 35 (almost one third of the 1115 stores)
store_info_df[store_info_df['CompetitionOpenSinceMonth'].isnull()]
# Out:
#       Store StoreType Assortment  CompetitionDistance  \
# 11       12         a          c               1070.0
# 12       13         d          a                310.0
# 15       16         a          c               3270.0
# 18       19         a          c               3240.0
# 21       22         a          a               1040.0
# ...     ...       ...        ...                  ...
# 1095   1096         a          c               1130.0
# 1099   1100         a          a                540.0
# 1112   1113         a          c               9260.0
# 1113   1114         a          c                870.0
# 1114   1115         d          c               5350.0
#
#       CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 11                          NaN                       NaN       1
# 12                          NaN                       NaN       1
# 15                          NaN                       NaN       0
# 18                          NaN                       NaN       1
# 21                          NaN                       NaN       1
# ...                         ...                       ...     ...
# 1095                        NaN                       NaN       1
# 1099                        NaN                       NaN       1
# 1112                        NaN                       NaN       0
# 1113                        NaN                       NaN       0
# 1114                        NaN                       NaN       1
#
#       Promo2SinceWeek  Promo2SinceYear     PromoInterval
# 11               13.0           2010.0   Jan,Apr,Jul,Oct
# 12               45.0           2009.0   Feb,May,Aug,Nov
# 15                NaN              NaN               NaN
# 18               22.0           2011.0  Mar,Jun,Sept,Dec
# 21               22.0           2012.0   Jan,Apr,Jul,Oct
# ...               ...              ...               ...
# 1095             10.0           2014.0  Mar,Jun,Sept,Dec
# 1099             14.0           2011.0   Jan,Apr,Jul,Oct
# 1112              NaN              NaN               NaN
# 1113              NaN              NaN               NaN
# 1114             22.0           2012.0  Mar,Jun,Sept,Dec
#
# [354 rows x 10 columns]

# %%
store_info_df[store_info_df['Promo2'] == 0]
# Out:
#       Store StoreType Assortment  CompetitionDistance  \
# 0         1         c          a               1270.0
# 3         4         c          c                620.0
# 4         5         a          a              29910.0
# 5         6         a          a                310.0
# 6         7         a          c              24000.0
# ...     ...       ...        ...                  ...
# 1107   1108         a          a                540.0
# 1109   1110         c          c                900.0
# 1111   1112         c          c               1880.0
# 1112   1113         a          c               9260.0
# 1113   1114         a          c                870.0
#
#       CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                           9.0                    2008.0       0
# 3                           9.0                    2009.0       0
# 4                           4.0                    2015.0       0
# 5                          12.0                    2013.0       0
# 6                           4.0                    2013.0       0
# ...                         ...                       ...     ...
# 1107                        4.0                    2004.0       0
# 1109                        9.0                    2010.0       0
# 1111                        4.0                    2006.0       0
# 1112                        NaN                       NaN       0
# 1113                        NaN                       NaN       0
#
#       Promo2SinceWeek  Promo2SinceYear PromoInterval
# 0                 NaN              NaN           NaN
# 3                 NaN              NaN           NaN
# 4                 NaN              NaN           NaN
# 5                 NaN              NaN           NaN
# 6                 NaN              NaN           NaN
# ...               ...              ...           ...
# 1107              NaN              NaN           NaN
# 1109              NaN              NaN           NaN
# 1111              NaN              NaN           NaN
# 1112              NaN              NaN           NaN
# 1113              NaN              NaN           NaN
#
# [544 rows x 10 columns]

# %%
str_cols = ['Promo2SinceWeek', 'Promo2SinceYear', 'PromoInterval', 'CompetitionOpenSinceYear', 'CompetitionOpenSinceMonth']

for col in str_cols:
    store_info_df[col] = store_info_df[col].fillna(0)

# %% [markdown]
# this code iterates through specific columns in the store_info_df and fills any missing values in those columns with 0

# %%
sns.heatmap(store_info_df.isnull(), yticklabels = False, cbar = False, cmap = 'Blues')
# Out:
# <Axes: >

# %%
#there are 3 rows with 'competitionDistance' values missing, let's fill them up with average values of the 'competitionDistance' column
store_info_df['CompetitionDistance'] = store_info_df['CompetitionDistance'].fillna(store_info_df['CompetitionDistance'].mean())

# %%
sns.heatmap(store_info_df.isnull(), yticklabels = False, cbar = False, cmap = 'Blues')
# Out:
# <Axes: >

# %%
store_info_df.hist(bins = 30, figsize = (20, 20), color = 'r')
# Out:
# array([[<Axes: title={'center': 'Store'}>,
#         <Axes: title={'center': 'CompetitionDistance'}>,
#         <Axes: title={'center': 'CompetitionOpenSinceMonth'}>],
#        [<Axes: title={'center': 'CompetitionOpenSinceYear'}>,
#         <Axes: title={'center': 'Promo2'}>,
#         <Axes: title={'center': 'Promo2SinceWeek'}>],
#        [<Axes: title={'center': 'Promo2SinceYear'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %% [markdown]
# EXPLORE MERGED DATASET
# L

# %%
#let's merge both dataframes together based on 'store'
sales_train_all_df = pd.merge(sales_train_df, store_info_df, how = 'inner', on = 'Store')

# %%
sales_train_all_df.to_csv('test.csv', index = False)

# %%
sales_train_all_df
# Out:
#         Store  DayOfWeek        Date  Sales  Customers  Promo StateHoliday  \
# 0           1          5  2015-07-31   5263        555      1            0
# 1           2          5  2015-07-31   6064        625      1            0
# 2           3          5  2015-07-31   8314        821      1            0
# 3           4          5  2015-07-31  13995       1498      1            0
# 4           5          5  2015-07-31   4822        559      1            0
# ...       ...        ...         ...    ...        ...    ...          ...
# 844387    682          2  2013-01-01   3375        566      0            a
# 844388    733          2  2013-01-01  10765       2377      0            a
# 844389    769          2  2013-01-01   5035       1248      0            a
# 844390    948          2  2013-01-01   4491       1039      0            a
# 844391   1097          2  2013-01-01   5961       1405      0            a
#
#         SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0                   1         c          a               1270.0
# 1                   1         a          a                570.0
# 2                   1         a          a              14130.0
# 3                   1         c          c                620.0
# 4                   1         a          a              29910.0
# ...               ...       ...        ...                  ...
# 844387              1         b          a                150.0
# 844388              1         b          b                860.0
# 844389              1         b          b                840.0
# 844390              1         b          b               1430.0
# 844391              1         b          b                720.0
#
#         CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                             9.0                    2008.0       0
# 1                            11.0                    2007.0       1
# 2                            12.0                    2006.0       1
# 3                             9.0                    2009.0       0
# 4                             4.0                    2015.0       0
# ...                           ...                       ...     ...
# 844387                        9.0                    2006.0       0
# 844388                       10.0                    1999.0       0
# 844389                        0.0                       0.0       1
# 844390                        0.0                       0.0       0
# 844391                        3.0                    2002.0       0
#
#         Promo2SinceWeek  Promo2SinceYear    PromoInterval
# 0                   0.0              0.0                0
# 1                  13.0           2010.0  Jan,Apr,Jul,Oct
# 2                  14.0           2011.0  Jan,Apr,Jul,Oct
# 3                   0.0              0.0                0
# 4                   0.0              0.0                0
# ...                 ...              ...              ...
# 844387              0.0              0.0                0
# 844388              0.0              0.0                0
# 844389             48.0           2012.0  Jan,Apr,Jul,Oct
# 844390              0.0              0.0                0
# 844391              0.0              0.0                0
#
# [844392 rows x 17 columns]

# %%
# Convert 'Date' column to datetime objects if it's not already
sales_train_all_df['Date'] = pd.to_datetime(sales_train_all_df['Date'])

# Extract numerical features for correlation analysis
numerical_features = sales_train_all_df.select_dtypes(include=['number'])

# Calculate correlations on numerical features only
correlations = numerical_features.corr()['Sales'].sort_values()

# %%
correlations
# Out:
# DayOfWeek                   -0.178736
# Promo2SinceYear             -0.127621
# Promo2                      -0.127596
# Promo2SinceWeek             -0.058476
# CompetitionDistance         -0.036343
# CompetitionOpenSinceMonth   -0.018370
# CompetitionOpenSinceYear     0.005266
# Store                        0.007710
# SchoolHoliday                0.038617
# Promo                        0.368145
# Customers                    0.823597
# Sales                        1.000000
# Name: Sales, dtype: float64

# %%
numerical_features = sales_train_all_df.select_dtypes(include=['number'])
correlations = numerical_features.corr()

f, ax = plt.subplots(figsize=(20, 20))
sns.heatmap(correlations, annot=True)
# Out:
# <Axes: >

# %%
#let's separate the year and put it into a separate column
sales_train_all_df['Year'] = pd.DatetimeIndex(sales_train_all_df['Date']).year

# %%
sales_train_all_df
# Out:
#         Store  DayOfWeek       Date  Sales  Customers  Promo StateHoliday  \
# 0           1          5 2015-07-31   5263        555      1            0
# 1           2          5 2015-07-31   6064        625      1            0
# 2           3          5 2015-07-31   8314        821      1            0
# 3           4          5 2015-07-31  13995       1498      1            0
# 4           5          5 2015-07-31   4822        559      1            0
# ...       ...        ...        ...    ...        ...    ...          ...
# 844387    682          2 2013-01-01   3375        566      0            a
# 844388    733          2 2013-01-01  10765       2377      0            a
# 844389    769          2 2013-01-01   5035       1248      0            a
# 844390    948          2 2013-01-01   4491       1039      0            a
# 844391   1097          2 2013-01-01   5961       1405      0            a
#
#         SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0                   1         c          a               1270.0
# 1                   1         a          a                570.0
# 2                   1         a          a              14130.0
# 3                   1         c          c                620.0
# 4                   1         a          a              29910.0
# ...               ...       ...        ...                  ...
# 844387              1         b          a                150.0
# 844388              1         b          b                860.0
# 844389              1         b          b                840.0
# 844390              1         b          b               1430.0
# 844391              1         b          b                720.0
#
#         CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                             9.0                    2008.0       0
# 1                            11.0                    2007.0       1
# 2                            12.0                    2006.0       1
# 3                             9.0                    2009.0       0
# 4                             4.0                    2015.0       0
# ...                           ...                       ...     ...
# 844387                        9.0                    2006.0       0
# 844388                       10.0                    1999.0       0
# 844389                        0.0                       0.0       1
# 844390                        0.0                       0.0       0
# 844391                        3.0                    2002.0       0
#
#         Promo2SinceWeek  Promo2SinceYear    PromoInterval  Year
# 0                   0.0              0.0                0  2015
# 1                  13.0           2010.0  Jan,Apr,Jul,Oct  2015
# 2                  14.0           2011.0  Jan,Apr,Jul,Oct  2015
# 3                   0.0              0.0                0  2015
# 4                   0.0              0.0                0  2015
# ...                 ...              ...              ...   ...
# 844387              0.0              0.0                0  2013
# 844388              0.0              0.0                0  2013
# 844389             48.0           2012.0  Jan,Apr,Jul,Oct  2013
# 844390              0.0              0.0                0  2013
# 844391              0.0              0.0                0  2013
#
# [844392 rows x 18 columns]

# %%
#let's do the same for the day and month
sales_train_all_df['Month'] = pd.DatetimeIndex(sales_train_all_df['Date']).month
sales_train_all_df['Day'] = pd.DatetimeIndex(sales_train_all_df['Date']).day

# %%
sales_train_all_df
# Out:
#         Store  DayOfWeek       Date  Sales  Customers  Promo StateHoliday  \
# 0           1          5 2015-07-31   5263        555      1            0
# 1           2          5 2015-07-31   6064        625      1            0
# 2           3          5 2015-07-31   8314        821      1            0
# 3           4          5 2015-07-31  13995       1498      1            0
# 4           5          5 2015-07-31   4822        559      1            0
# ...       ...        ...        ...    ...        ...    ...          ...
# 844387    682          2 2013-01-01   3375        566      0            a
# 844388    733          2 2013-01-01  10765       2377      0            a
# 844389    769          2 2013-01-01   5035       1248      0            a
# 844390    948          2 2013-01-01   4491       1039      0            a
# 844391   1097          2 2013-01-01   5961       1405      0            a
#
#         SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0                   1         c          a               1270.0
# 1                   1         a          a                570.0
# 2                   1         a          a              14130.0
# 3                   1         c          c                620.0
# 4                   1         a          a              29910.0
# ...               ...       ...        ...                  ...
# 844387              1         b          a                150.0
# 844388              1         b          b                860.0
# 844389              1         b          b                840.0
# 844390              1         b          b               1430.0
# 844391              1         b          b                720.0
#
#         CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                             9.0                    2008.0       0
# 1                            11.0                    2007.0       1
# 2                            12.0                    2006.0       1
# 3                             9.0                    2009.0       0
# 4                             4.0                    2015.0       0
# ...                           ...                       ...     ...
# 844387                        9.0                    2006.0       0
# 844388                       10.0                    1999.0       0
# 844389                        0.0                       0.0       1
# 844390                        0.0                       0.0       0
# 844391                        3.0                    2002.0       0
#
#         Promo2SinceWeek  Promo2SinceYear    PromoInterval  Year  Month  Day
# 0                   0.0              0.0                0  2015      7   31
# 1                  13.0           2010.0  Jan,Apr,Jul,Oct  2015      7   31
# 2                  14.0           2011.0  Jan,Apr,Jul,Oct  2015      7   31
# 3                   0.0              0.0                0  2015      7   31
# 4                   0.0              0.0                0  2015      7   31
# ...                 ...              ...              ...   ...    ...  ...
# 844387              0.0              0.0                0  2013      1    1
# 844388              0.0              0.0                0  2013      1    1
# 844389             48.0           2012.0  Jan,Apr,Jul,Oct  2013      1    1
# 844390              0.0              0.0                0  2013      1    1
# 844391              0.0              0.0                0  2013      1    1
#
# [844392 rows x 20 columns]

# %%
#let's take a look at the average sales and number of customers per month
#'groupby' works great by grouping all the data that share the same month column,
#it looks likes sales and number of customers peak around christmas timeframe
axis = sales_train_all_df.groupby('Month')[['Sales']].mean().plot(figsize = (10, 5), marker = 'o', color= 'r')
axis.set_title('Average Sales Per Month')

plt.figure()
axis = sales_train_all_df.groupby('Month')[['Customers']].mean().plot(figsize = (10, 5), marker = '^', color= 'b')
axis.set_title('Average Customers Per Month')
# Out:
# Text(0.5, 1.0, 'Average Customers Per Month')

# %%
#let's take a look at the sales and customers per day of the month instead
#Minimum number of customers are generally around the 24th of the month
#Most customers and sales are around 30th and 1st of the month
ax = sales_train_all_df.groupby('Day')[['Sales']].mean().plot(figsize = (10, 5), marker = 'o', color = 'r')
axis.set_title('Average Sales Per Day')

plt.figure()
ax = sales_train_all_df.groupby('Day')[['Customers']].mean().plot(figsize = (10, 5), marker = '^', color = 'b')
axis.set_title('Average Sales Per Day')
# Out:
# Text(0.5, 1.0, 'Average Sales Per Day')

# %%
#let's do the same for the day of the week (note that 7 = Sunday)
axis = sales_train_all_df.groupby('DayOfWeek')[['Sales']].mean().plot(figsize = (10, 5), marker = 'o', color = 'r')
axis.set_title('Average Sales Per Day of the Week')

plt.figure()
axis = sales_train_all_df.groupby('DayOfWeek')[['Customers']].mean().plot(figsize = (10, 5), marker = '^', color = 'b')
axis.set_title('Average Customers Per Day of the week')
# Out:
# Text(0.5, 1.0, 'Average Customers Per Day of the week')

# %%
fig, ax = plt.subplots(figsize=(20, 10))
#Only calculate the mean of the Sales column and exclude non-numeric columns
sales_train_all_df.groupby(['Date', 'StoreType'])['Sales'].mean().unstack().plot(ax=ax)
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# Differences between store types:
# - Stores of type d (orange) consistently show the highest average sales
# - stores of type a (blue) tend to have the lowest average sales.
# - Stores b and c fall within an intermediate range, with distinct behavior patterns

# %%
plt.figure(figsize = [15, 10])

plt.subplot(211)
sns.barplot(x = 'Promo', y = 'Sales', data = sales_train_all_df)

plt.subplot(212)
sns.barplot(x = 'Promo', y = 'Customers', data = sales_train_all_df)
# Out:
# <Axes: xlabel='Promo', ylabel='Customers'>

# %% [markdown]
# When promotions are in place (Promo = 1), sales are significantly higher compared to when there are no promotions (promo = 0)
#
# Promotions have a positive impact on both increasing sales and attracting more customers. This suggests that promotions are effective in drawing more consumers and boosting revenue.

# %%
plt.figure(figsize = [15, 10])

plt.subplot(211)
sns.violinplot(x = 'Promo', y = 'Sales', data = sales_train_all_df)

plt.subplot(212)
sns.violinplot(x = 'Promo', y = 'Customers', data = sales_train_all_df)
# Out:
# <Axes: xlabel='Promo', ylabel='Customers'>

# %% [markdown]
# When there are no promotions, sales are concentrated at lower values, with some occurrences of higher sales(outliers)
#
# General conclusion:
# The violin plots confirm that promotions have a significant impact on increasing both sales and the number of customers

# %% [markdown]
# #UNDERSTAND THE INTUITION BEHIND FACEBOOK PROPHET
#
# -Prophet is open source software released by facebooks core data science team
# - Is a procedure for forecasting time series data based on an additive model where non-linear trends are fit with yearly, weekly, and daily seasonality, plus holiday effects
#
# - Implements an additive regression model with four elements:
#
# - A piecewise linear, Prophet automatically picks up change points in the data and identifies any change in trends
#
# - ACCURATE AND FAST
#  - Facebook teams uses Prophet for accurate forecasting and planning
#  - Prophet can generate results in seconds
#
# - AUTOMATIC
#  - No need to perform data preprocessing
#  - Prophet works with missing data with several outliers
#
# -DOMAIN KNOWLEDGE INTEGRATION
#   - Users can tweak forecast by manually adding domain specific knowledge
#
# Use cases:
# - sales forecasting
# - Resource and inventory planning
# - Traffic forecasting for websites or applications
# - Monitoring business metrics

# %% [markdown]
# #TRAIN THE MODEL PART A

# %%
# !pip install prophet
# !pip install cython numpy pandas matplotlib setuptools git pystan cmdstanpy
# Out:
# Requirement already satisfied: prophet in /usr/local/lib/python3.10/dist-packages (1.1.6)
# Requirement already satisfied: cmdstanpy>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from prophet) (1.2.5)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.10/dist-packages (from prophet) (1.26.4)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from prophet) (3.8.0)
# Requirement already satisfied: pandas>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from prophet) (2.2.2)
# Requirement already satisfied: holidays<1,>=0.25 in /usr/local/lib/python3.10/dist-packages (from prophet) (0.63)
# Requirement already satisfied: tqdm>=4.36.1 in /usr/local/lib/python3.10/dist-packages (from prophet) (4.67.1)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from prophet) (6.4.5)
# Requirement already satisfied: stanio<2.0.0,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from cmdstanpy>=1.0.4->prophet) (0.5.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from holidays<1,>=0.25->prophet) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (3.2.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.4->prophet) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.4->prophet) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil->holidays<1,>=0.25->prophet) (1.17.0)
# Requirement already satisfied: cython in /usr/local/lib/python3.10/dist-packages (3.0.11)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.8.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (75.1.0)
# ERROR: Could not find a version that satisfies the requirement git (from versions: none)
# ERROR: No matching distribution found for git

# %%
# Ensure fbprophet is installed and the kernel is restarted.


# Import the Prophet class from fbprophet
from prophet import Prophet

# %%
def sales_prediction(Store_ID, sales_df, periods):
  #Function that takes in the data frame, storeID, and number of future period forecast
  #the function then generates date/sales columns in Prophet format
  #The function then makes time series predictions
#this function takes historical sales data for a specific store, trains a forecasting model using that data, and then uses the
#model to predict future sales and visualize the results


  sales_df = sales_df[sales_df['Store'] == Store_ID]
  sales_df = sales_df[['Date', 'Sales']].rename(columns = {'Date': 'ds', 'Sales': 'y'})
  sales_df = sales_df.sort_values('ds')

  model = Prophet()
  model.fit(sales_df)
  future = model.make_future_dataframe(periods=periods)
  forecast = model.predict(future)
  figure = model.plot(forecast, xlabel = 'Date', ylabel = 'Sales')
  figure2 = model.plot_components(forecast)

# %%
sales_prediction(10, sales_train_all_df, 60)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpt6aia859/mbcuzpyp.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpt6aia859/c59rh0y2.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=41583', 'data', 'file=/tmp/tmpt6aia859/mbcuzpyp.json', 'init=/tmp/tmpt6aia859/c59rh0y2.json', 'output', 'file=/tmp/tmpt6aia859/prophet_model9b6sg4it/prophet_model-20250114193549.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 19:35:49 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:35:49 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %% [markdown]
# the top plot shows the observed sales (black dots) along with the models predicted values (blue line)
# The shaded blue area represents the confidence intervals of the predictions
# - sales exhibit seasonal fluctiations over time with periodic spikes, suggesting cyclic or weekly behavior

# %% [markdown]
# #TRAIN THE MODEL PART B
#
# - StateHoliday: indicates a state holiday. Normally all stores, with few exceptions, are closed on state holidays. Note that all schools are closed on public holidays and weekends. a = public holiday, b = Easter Holiday, c = Christmas, 0 = None
# - SchoolHoliday: indicates if the (Store, Date) was affected by the closure of public schools

# %%
def sales_prediction(Store_ID, sales_df, holidays, periods):
  #function that takes in the storeId and returns two date/sales columns in prophet format
  #format data to fit prophet

  sales_df = sales_df[ sales_df['Store'] == Store_ID]
  sales_df = sales_df[['Date', 'Sales']].rename(columns = {'Date': 'ds', 'Sales':'y'})
  sales_df = sales_df.sort_values('ds')

  model = Prophet(holidays = holidays)
  model.fit(sales_df)
  future = model.make_future_dataframe(periods = periods)
  forecast = model.predict(future)
  figure = model.plot(forecast, xlabel = 'Date', ylabel = 'Sales')
  figure2 = model.plot_components(forecast)

# %%
#get all the dates pertaining to school holidays
school_holidays  = sales_train_all_df[sales_train_all_df['SchoolHoliday'] == 1].loc[:, 'Date'].values
school_holidays.shape
# Out:
# (163457,)

# %%
school_holidays
# Out:
# array(['2015-07-31T00:00:00.000000000', '2015-07-31T00:00:00.000000000',
#        '2015-07-31T00:00:00.000000000', ...,
#        '2013-01-01T00:00:00.000000000', '2013-01-01T00:00:00.000000000',
#        '2013-01-01T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
#get all the dates pertaining to state holidays
state_holidays = sales_train_all_df[ (sales_train_all_df['StateHoliday'] == 'a') | (sales_train_all_df['StateHoliday'] == 'b') | (sales_train_all_df['StateHoliday'] == 'c') ].loc[:, 'Date'].values
state_holidays.shape
# Out:
# (910,)

# %%
state_holidays = pd.DataFrame({'ds': pd.to_datetime(state_holidays),
                               'holiday': 'state_holiday'})

# %%
state_holidays
# Out:
#             ds        holiday
# 0   2015-06-04  state_holiday
# 1   2015-06-04  state_holiday
# 2   2015-06-04  state_holiday
# 3   2015-06-04  state_holiday
# 4   2015-06-04  state_holiday
# ..         ...            ...
# 905 2013-01-01  state_holiday
# 906 2013-01-01  state_holiday
# 907 2013-01-01  state_holiday
# 908 2013-01-01  state_holiday
# 909 2013-01-01  state_holiday
#
# [910 rows x 2 columns]

# %%
school_holidays = pd.DataFrame({'ds': pd.to_datetime(school_holidays),
                               'holiday': 'school_holiday'})

# %%
school_holidays
# Out:
#                ds         holiday
# 0      2015-07-31  school_holiday
# 1      2015-07-31  school_holiday
# 2      2015-07-31  school_holiday
# 3      2015-07-31  school_holiday
# 4      2015-07-31  school_holiday
# ...           ...             ...
# 163452 2013-01-01  school_holiday
# 163453 2013-01-01  school_holiday
# 163454 2013-01-01  school_holiday
# 163455 2013-01-01  school_holiday
# 163456 2013-01-01  school_holiday
#
# [163457 rows x 2 columns]

# %%
#concatenate both school and state holidays
school_state_holidays = pd.concat((state_holidays, school_holidays))

# %%
school_state_holidays
# Out:
#                ds         holiday
# 0      2015-06-04   state_holiday
# 1      2015-06-04   state_holiday
# 2      2015-06-04   state_holiday
# 3      2015-06-04   state_holiday
# 4      2015-06-04   state_holiday
# ...           ...             ...
# 163452 2013-01-01  school_holiday
# 163453 2013-01-01  school_holiday
# 163454 2013-01-01  school_holiday
# 163455 2013-01-01  school_holiday
# 163456 2013-01-01  school_holiday
#
# [164367 rows x 2 columns]

# %%
#let's make prediction using holidays for a specific store
sales_prediction(6, sales_train_all_df, school_state_holidays, 60)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpt6aia859/0_erzhse.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpt6aia859/5_m82hzm.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=86332', 'data', 'file=/tmp/tmpt6aia859/0_erzhse.json', 'init=/tmp/tmpt6aia859/5_m82hzm.json', 'output', 'file=/tmp/tmpt6aia859/prophet_modelby4t53av/prophet_model-20250114202529.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:25:29 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:25:29 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %% [markdown]
# # Summary of Forecast Model Insights:
# - Holiday Impact: Holidays clearly generate sales spikes, highlighting their importance for forecasts and business strategies.
# - Weekly Seasonality: Sales are highest on Monday and consistently decrease until Saturday.
# - Annual Seasonality: Sales peak in November and December (seasonal events), while January shows declines.
# - Overall Trend: Despite seasonal patterns, sales are decreasing over time.
# - Model Fit: The model captures key patterns well but could be improved by incorporating additional external variables.
# - Strategic Recommendations:
# - Promotions: Focus on November, December, and Mondays.
# - Planning: Adjust stock and campaigns for holidays and seasonal events.
# Investigation: Identify causes of the overall trend decline to reverse it.
